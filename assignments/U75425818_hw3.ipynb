# %%
#Homework 3: Integration - Abraham Cepeda Oseguera - BUID: U75425818
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 107.0 kB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 93.6 kB/s eta 0:00:00a 0:00:01
# ...

# %%
#Problem 1. 
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (1 , 5 , 100) # x value - continuous
n = np.arange (1 , 6 , 1) # n values (1,2,3,4,5)

#1. f(x) = 1 --> x
def f1(x):
    return x

height = [f1(1* i) for i in range (1,6)] #height values

plt.plot(x, f1(x), color="green")
plt.title("1. $f(x) = $x")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

#2. f(x) = x --> (x^2)/2
def f2(x):
    return (x*x)/2

height = [f2(1* i) for i in range (1,6)] #height values

plt.plot(x, f2(x), color="green")
plt.title("2. $f(x) = $(x^2)/2")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()


#3. f(x) = x^2 --> (x^3)/3
def f3(x):
    return pow(x,3)/3

height = [f3(1* i) for i in range (1,6)] #height values

plt.plot(x, f3(x), color="green")
plt.title("3. $f(x) = $(x^3)/3")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()


#4. f(x) = x^3 --> (x^4)/4
def f4(x):
    return pow(x,4)/4

height = [f4(1* i) for i in range (1,6)] #height values

plt.plot(x, f4(x), color="green")
plt.title("4. $f(x) = $(x^4)/4")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()


#5. f(x) = √x --> (2/3)*x^(3/2)
def f5(x):
    return (2/3)*pow(x, 3/2)

height = [f5(1* i) for i in range (1,6)] #height values

plt.plot(x, f5(x), color="green")
plt.title("5. $f(x) = $(2/3)*x^(3/2)")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

#6. f(x) = e^x --> e^x
def f6(x):
    return np.exp(x)

height = [f6(1* i) for i in range (1,6)] #height values

plt.plot(x, f6(x), color="green")
plt.title("6. $f(x) = $e^x")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

#7. f(x) = 2^x --> 2^x/(log(2))
def f7(x):
    return pow(2,x)/np.log(2)

height = [f7(1* i) for i in range (1,6)] #height values

plt.plot(x, f7(x), color="green")
plt.title("7. $f(x) = $2^x/(log(2))")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

#8. f(x) = log(x) --> xlog(x)-x
def f8(x):
    return x*np.log(x)-x

height = [f8(1* i) for i in range (1,6)] #height values

plt.plot(x, f8(x), color="green")
plt.title("8. $f(x) = $xlog(x)-x")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()


#9. f(x) = sin(x) --> -cos(x)
def f9(x):
    return -1*np.cos(x)

height = [f9(1* i) for i in range (1,6)] #height values

plt.plot(x, f9(x), color="green")
plt.title("9. $f(x) = $-cos(x)")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

#10. f(x) = cos(x) --> sin(x)
def f10(x):
    return np.sin(x)

height = [f10(1* i) for i in range (1,6)] #height values

plt.plot(x, f10(x), color="green")
plt.title("10. $f(x) = $sin(x)")
plt.bar(n, height, width = 1,alpha = 0.9, color="red")
plt.show()

# %%
#Problem 2 - Compute intergral using sympy
import sympy as sym


x = sym.Symbol('x')


#1. f(x) = 1
print("1. ", sym.integrate(1, x))

#2. f(x) = x
print("2. ", sym.integrate(x, x))

#3. f(x) = x^2
print("3. ", sym.integrate(x*x, x))

#4. f(x) = x^3
print("4. ", sym.integrate(pow(x,3), x))

#5. f(x) = √x
print("5. ", sym.integrate(sym.sqrt(x), x))

#6. f(x) = e^x
print("6. ", sym.integrate(sym.exp(x), x))

#7. f(x) = 2^x
print("7. ", sym.integrate(pow(2,x), x))

#8. f(x) = log(x)
print("8. ", sym.integrate(sym.log(x), x))

#9. f(x) = sin(x)
print("9. ", sym.integrate(sym.sin(x), x))

#10. f(x) = cos(x)
print("10. ", sym.integrate(sym.cos(x), x))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/90/1szcyrc121j6sqbkk9pcwj3w0000gn/T/ipykernel_49229/1906023732.py in <module>
#       1 #Problem 2 - Compute intergral using sympy
# ----> 2 import sympy as sym
#       3
#       4
#       5 x = sym.Symbol('x')
#
# ModuleNotFoundError: No module named 'sympy'

# %%
#Problem 3 - Compute intergral using sympy from 1 to 5
import sympy as sym


x = sym.Symbol('x')


#1. f(x) = 1
print("1. ", sym.integrate(1, (x, 1, 5)))

#2. f(x) = x
print("2. ", sym.integrate(x, (x, 1, 5)))

#3. f(x) = x^2
print("3. ", sym.integrate(x*x, (x, 1, 5)))

#4. f(x) = x^3
print("4. ", sym.integrate(pow(x,3), (x, 1, 5)))

#5. f(x) = √x
print("5. ", sym.integrate(sym.sqrt(x), (x, 1, 5)))

#6. f(x) = e^x
print("6. ", sym.integrate(sym.exp(x), (x, 1, 5)))

#7. f(x) = 2^x
print("7. ", sym.integrate(pow(2,x), (x, 1, 5)))

#8. f(x) = log(x)
print("8. ", sym.integrate(sym.log(x), (x, 1, 5)))

#9. f(x) = sin(x)
print("9. ", sym.integrate(sym.sin(x), (x, 1, 5)))

#10. f(x) = cos(x)
print("10. ", sym.integrate(sym.cos(x), (x, 1, 5)))
# Out:
# 1.  4
# 2.  12
# 3.  124/3
# 4.  156
# 5.  -2/3 + 10*sqrt(5)/3
# 6.  -E + exp(5)
# 7.  30/log(2)
# 8.  -4 + 5*log(5)
# 9.  -cos(5) + cos(1)
# 10.  sin(5) - sin(1)

# %%
#Problem 4 - Compute integral with fixed quadrature, simpson, and trapezoid from 1 to 5
import scipy . integrate as spi
import numpy as np

a, b= 1 , 5



###1. f(x) = 1
integrand = lambda x : x-x+1

#fixed quadrature
res, err = spi.fixed_quad(integrand,a,b)
print ("1. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("1. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("1. trapezoid   = ", round(res,3))


###2. f(x) = x
print("--------")
integrand = lambda x: x

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("2. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("2. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("2. trapezoid   = ", round(res,3))


#3. f(x) = x^2
print("--------")
integrand = lambda x: x*x

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("3. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("3. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("3. trapezoid   = ", round(res,3))


#4. f(x) = x^3
print("--------")
integrand = lambda x: pow(x,3)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("4. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("4. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("4. trapezoid   = ", round(res,3))


#5. f(x) = √x
print("--------")
integrand = lambda x: np.sqrt(x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("5. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("5. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("5. trapezoid   = ", round(res,3))

#6. f(x) = e^x
print("--------")
integrand = lambda x: np.exp(x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("6. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("6. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("6. trapezoid   = ", round(res,3))


#7. f(x) = 2^x
print("--------")
integrand = lambda x: pow(2,x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("7. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("7. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("7. trapezoid   = ", round(res,3))


#8. f(x) = log(x)
print("--------")
integrand = lambda x: np.log(x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("8. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("8. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("8. trapezoid   = ", round(res,3))


#9. f(x) = sin(x)
print("--------")
integrand = lambda x: np.sin(x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("9. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("9. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("9. trapezoid   = ", round(res,3))


#10. f(x) = cos(x)
print("--------")
integrand = lambda x: np.cos(x)

#fixed quadrature
res, err = spi.quad(integrand,a,b)
print ("10. quadrature  = ", round(res,3))

#trapezoid
step = 1e-4
xs = np.arange(a, b, step)
ys = integrand(xs)
res = spi.trapezoid(ys , xs)
print ("10. simpson     = ", round(res,3))

#simpson
res = spi.simpson(ys , xs)
print ("10. trapezoid   = ", round(res,3))
# Out:
# 1. quadrature  =  4.0
# 1. simpson     =  4.0
# 1. trapezoid   =  4.0
# --------
# 2. quadrature  =  12.0
# 2. simpson     =  12.0
# 2. trapezoid   =  12.0
# --------
# 3. quadrature  =  41.333
# 3. simpson     =  41.331
# 3. trapezoid   =  41.331
# --------
# 4. quadrature  =  156.0
# 4. simpson     =  155.988
# 4. trapezoid   =  155.988
# --------
# 5. quadrature  =  6.787
# 5. simpson     =  6.787
# 5. trapezoid   =  6.787
# --------
# 6. quadrature  =  145.695
# 6. simpson     =  145.68
# 6. trapezoid   =  145.68
# --------
# 7. quadrature  =  43.281
# 7. simpson     =  43.278
# 7. trapezoid   =  43.278
# --------
# 8. quadrature  =  4.047
# 8. simpson     =  4.047
# 8. trapezoid   =  4.047
# --------
# 9. quadrature  =  0.257
# 9. simpson     =  0.257
# 9. trapezoid   =  0.257
# --------
# 10. quadrature  =  -1.8
# 10. simpson     =  -1.8
# 10. trapezoid   =  -1.8

# %%
##Problem 5 - Compute integral numerically
import numpy as np

a = [1,2,3,4]
b = [2,3,4,5]
c_sum = 0

#Quadrature function
def quad(f, i):
    return (f(a[i]) + f(b[i])) / 2

#Trapezoid function
def trap(f, i):
    return f((a[i] + b[i]) / 2)

#Simpson function
def simp(f, i):
    return (f(a[i]) + 4 * f((a[i] + b[i]) / 2) + f(b[i])) / 6



#1. f(x) = 1
def f1(x):
    return x-x+1


#2. f(x) = x
def f2(x):
    return x


#3. f(x) = x^2
def f3(x):
    return x*x

#4. f(x) = x^3
def f4(x):
    return pow(x,3)


#5. f(x) = √x
def f5(x):
    return np.sqrt(x)


#6. f(x) = e^x
def f6(x):
    return np.exp(x)


#7. f(x) = 2^x
def f7(x):
    return pow(2,x)


#8. f(x) = log(x)
def f8(x):
    return np.log(x)


#9. f(x) = sin(x)
def f9(x):
    return np.sin(x)

#10. f(x) = cos(x)
def f10(x):
    return np.cos(x)


fs = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10]

for e in range(10):
    c_sum = 0
    print("\n--------\n")
    
    
    print(e+1, ". F(x)")
    for i in range(4):
        res = fs[e](i+1)
        print(round(res,2))
    
    print(e+1, ". Trapezoid")
    for i in range(4):
        res = trap(fs[e], i)
        c_sum += res
        print(round(res,2))

    print("Tot = ", round(c_sum,2))
    c_sum = 0

    
    print(e+1, ". Quadrature")
    for i in range(4):
        res = quad(fs[e], i)
        c_sum += res
        print(round(res,2))

    
    print("Tot = ", round(c_sum,2))
    c_sum = 0
    

    print(e+1, ". Simpson")
    for i in range(4):
        res = simp(fs[e], i)
        c_sum += res
        print(round(res,2))
        
    print("Tot = ", round(c_sum,2))
    c_sum = 0
# Out:
# --------
#
# 1 . F(x)
# 1
# 1
# 1
# 1
# 1 . Trapezoid
# 1.0
# 1.0
# 1.0
# 1.0
# Tot =  4.0
# 1 . Quadrature
# 1.0
# 1.0
# 1.0
# 1.0
# Tot =  4.0
# 1 . Simpson
# 1.0
# 1.0
# 1.0
# 1.0
# Tot =  4.0
#
# --------
#
# 2 . F(x)
# 1
# 2
# 3
# 4
# 2 . Trapezoid
# 1.5
# 2.5
# 3.5
# 4.5
# Tot =  12.0
# 2 . Quadrature
# 1.5
# 2.5
# 3.5
# 4.5
# Tot =  12.0
# 2 . Simpson
# 1.5
# 2.5
# 3.5
# 4.5
# Tot =  12.0
#
# --------
#
# 3 . F(x)
# 1
# 4
# 9
# 16
# 3 . Trapezoid
# 2.25
# 6.25
# 12.25
# 20.25
# Tot =  41.0
# 3 . Quadrature
# 2.5
# 6.5
# 12.5
# 20.5
# Tot =  42.0
# 3 . Simpson
# 2.33
# 6.33
# 12.33
# 20.33
# Tot =  41.33
#
# --------
#
# 4 . F(x)
# 1
# 8
# 27
# 64
# 4 . Trapezoid
# 3.38
# 15.62
# 42.88
# 91.12
# Tot =  153.0
# 4 . Quadrature
# 4.5
# 17.5
# 45.5
# 94.5
# Tot =  162.0
# 4 . Simpson
# 3.75
# 16.25
# 43.75
# 92.25
# Tot =  156.0
#
# --------
#
# 5 . F(x)
# 1.0
# 1.41
# 1.73
# 2.0
# 5 . Trapezoid
# 1.22
# 1.58
# 1.87
# 2.12
# Tot =  6.8
# 5 . Quadrature
# 1.21
# 1.57
# 1.87
# 2.12
# ...

# %%
##Problem 6 - Calculate relative error
import numpy as np

a = [1,2,3,4]
b = [2,3,4,5]
c_sum = 0

#Quadrature function
def quad(f, i):
    return (f(a[i]) + f(b[i])) / 2

#Trapezoid function
def trap(f, i):
    return f((a[i] + b[i]) / 2)

#Simpson function
def simp(f, i):
    return (f(a[i]) + 4 * f((a[i] + b[i]) / 2) + f(b[i])) / 6



#1. f(x) = 1
def f1(x):
    return x-x+1


#2. f(x) = x
def f2(x):
    return x


#3. f(x) = x^2
def f3(x):
    return x*x

#4. f(x) = x^3
def f4(x):
    return pow(x,3)


#5. f(x) = √x
def f5(x):
    return np.sqrt(x)


#6. f(x) = e^x
def f6(x):
    return np.exp(x)


#7. f(x) = 2^x
def f7(x):
    return pow(2,x)


#8. f(x) = log(x)
def f8(x):
    return np.log(x)


#9. f(x) = sin(x)
def f9(x):
    return np.sin(x)

#10. f(x) = cos(x)
def f10(x):
    return np.cos(x)


fs = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10]


import sympy as sym


x = sym.Symbol('x')


real_values = [sym.integrate(1, (x, 1, 5)), 
               sym.integrate(x, (x, 1, 5)), 
               sym.integrate(x*x, (x, 1, 5)), 
               sym.integrate(pow(x,3), (x, 1, 5)),
               sym.integrate(sym.sqrt(x), (x, 1, 5)),
               sym.integrate(sym.exp(x), (x, 1, 5)),
               sym.integrate(pow(2,x), (x, 1, 5)),
               sym.integrate(sym.log(x), (x, 1, 5)),
               sym.integrate(sym.sin(x), (x, 1, 5)),
               sym.integrate(sym.cos(x), (x, 1, 5))
              ]

for e in range(10):
    c_sum = 0
    print("\n--------\n")

    real = real_values[e]
    
    print(e+1, ". Trapezoid")
    for i in range(4):
        res = trap(fs[e], i)
        c_sum += res

    print("Err = ", round( (c_sum - real)/real*100, 2) )
    c_sum = 0
    
    print(e+1, ". Quadrature")
    for i in range(4):
        res = quad(fs[e], i)
        c_sum += res

    
    print("Err = ", round((c_sum - real)/real*100, 2) )
    c_sum = 0
    

    print(e+1, ". Simpson")
    for i in range(4):
        res = simp(fs[e], i)
        c_sum += res
        
    print("Err = ", round((c_sum - real)/real*100, 2) )
    c_sum = 0
# Out:
# --------
#
# 1 . Trapezoid
# Err =  0
# 1 . Quadrature
# Err =  0
# 1 . Simpson
# Err =  0
#
# --------
#
# 2 . Trapezoid
# Err =  0
# 2 . Quadrature
# Err =  0
# 2 . Simpson
# Err =  0
#
# --------
#
# 3 . Trapezoid
# Err =  -0.81
# 3 . Quadrature
# Err =  1.61
# 3 . Simpson
# Err =  0.0
#
# --------
#
# 4 . Trapezoid
# Err =  -1.92
# 4 . Quadrature
# Err =  3.85
# 4 . Simpson
# Err =  0
#
# --------
#
# 5 . Trapezoid
# Err =  0.16
# 5 . Quadrature
# Err =  -0.33
# 5 . Simpson
# Err =  0.0
#
# --------
#
# 6 . Trapezoid
# Err =  -4.05
# 6 . Quadrature
# Err =  8.20
# 6 . Simpson
# Err =  0.03
#
# --------
#
# 7 . Trapezoid
# Err =  -1.97
# 7 . Quadrature
# Err =  3.97
# 7 . Simpson
# Err =  0.01
#
# --------
#
# 8 . Trapezoid
# Err =  0.78
# 8 . Quadrature
# Err =  -1.59
# 8 . Simpson
# Err =  -0.01
#
# --------
#
# 9 . Trapezoid
# Err =  4.29
# 9 . Quadrature
# Err =  -8.48
# 9 . Simpson
# Err =  0.04
#
# --------
#
# 10 . Trapezoid
# Err =  4.29
# 10 . Quadrature
# Err =  -8.48
# ...
