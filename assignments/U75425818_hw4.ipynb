# %%
#Homework 4: Root Finding - Abraham Cepeda Oseguera - BUID: U75425818

# %%
#Problem 1. Plot with Newton-Raphson Method
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (-3 , 3 , 100) # x value - continuous


def df(a, f):
    return (f(a +0.00001) - f(a))/0.00001

def tan_line(a, f):
    return df(a, f)*(x - a) + f(a)

def n(a, f):
    return a - f(a)/ df(a,f)


#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5

 
#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5


#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5


#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2


#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5


#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1


#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5


#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

for e in range(len(functions)):
    values = [3]
    for i in range (2):
        next_val = round(n(values[i], functions[e]),2)
        values.append(next_val)
    print("Values: ", values)
    plt.plot(x, functions[e](x), color="green")
    plt.plot(x2, tan_line(values[0], functions[e]), color = "red")
    plt.plot(x2, tan_line(values[1], functions[e]), color = "blue")
    plt.plot(x2, tan_line(values[2], functions[e]), color = "green")
    plt.title(f'{e+1}. {functions_text[e]}')
    plt.show()
# Out:
# Values:  [3, 2.33, 2.24]
# Values:  [3, 2.19, 1.81]
# Values:  [3, 2.2, 2.25]
# Values:  [3, 2.1, 1.34]
# Values:  [3, 1.65, 0.44]
# Values:  [3, 2.7, 2.72]
# Values:  [3, 2.64, 2.62]
# Values:  [3, -7.56, -7.34]

# %%
#Problem 2. Plot with Secant Method
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (-3 , 3 , 100) # x value - continuous



#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5

 
#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5


#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5


#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2


#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5


#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1


#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5


#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

def getSlope(f, xvals, count):
    return (f(xvals[count + 1]) - f(xvals[count]))/(xvals[count +1] - xvals[count])
                                                    
def getIntercept(f, slope, xvals, count):
    return -slope * xvals[count + 1] + f(xvals[count + 1])

for e in range(len(functions)):
    a = 0
    b = 3
    xvals = []
    xvals.append(a)
    xvals.append(b)
    cols = ['r', 'b', 'g']
    for i in range (3):
        slope = getSlope(functions[e], xvals, i)
        intercept = getIntercept(functions[e], slope, xvals, i)
        plt.plot(x, slope * x + intercept, cols[i])

        next_val = round(-intercept/slope,2)
        if abs(functions[e](next_val)) < 0.001:
            notconverge = 0
        else:
            xvals.append(next_val)
    print("Values: ", xvals)
    plt.plot(x, functions[e](x), color="green")
    plt.title(f'{e+1}. {functions_text[e]}')
    plt.show()
# Out:
# Values:  [0, 3, 1.67, 2.14, 2.25]
# Values:  [0, 3, 0.56, 1.0, 3.13]
# Values:  [0, 3, 2.6, 2.22]
# Values:  [0, 3, 0.16, 0.28, 0.82]
# Values:  [0, 3, -0.21, -0.37, -0.85]
# Values:  [0, 3, nan, nan, nan]
# Values:  [0, 3, 10.63, 0.45, -0.03]
# Values:  [0, 3, 0.75, 1.05, 1.05]

# %%
#Problem 3. Plot with Bisection Method
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (-3 , 3 , 100) # x value - continuous


#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5

 
#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5


#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5


#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2


#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5


#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1


#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5


#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

def getNext(f, a, b, mid):
    if (f(a) < 0 and f(mid) > 0 or f(a) > 0 and f(mid) < 0):
        return "a"
    else:
        return "b"

for e in range(len(functions)):
    a = -3
    b = 3
    xvals = []
    cols = ['r', 'b', 'g']
    for i in range (3):
        mid = (a + b)/2
        xvals.append(mid)
        
        if getNext(functions[e], a, b, mid) == "a":
            b = mid
        else:
            a = mid

    print("Values: ", xvals)
    plt.scatter(xvals, [0,0,0], s=50, c=cols)
    plt.plot(x, functions[e](x), color="green")
    plt.title(f'{e+1}. {functions_text[e]}')
    plt.show()
# Out:
# Values:  [0.0, -1.5, -2.25]
# Values:  [0.0, 1.5, 2.25]
# Values:  [0.0, 1.5, 2.25]
# Values:  [0.0, 1.5, 0.75]
# Values:  [0.0, -1.5, -0.75]
# Values:  [0.0, 1.5, 2.25]
# Values:  [0.0, 1.5, 0.75]
# Values:  [0.0, -1.5, -0.75]

# %%
#Problem 4. Compute with Newton-Raphson Method
import numpy as np

x = np.linspace (-3 , 3 , 100) # x value - continuous


def df(a, f):
    return (f(a +0.00001) - f(a))/0.00001

def n(a, f):
    return a - f(a)/ df(a,f)


#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5

#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5

#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5

#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2

#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5

#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1

#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5

#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

for e in range(len(functions)):
    values = [3]
    for i in range (3):
        next_val = round(n(values[i], functions[e]),2)
        values.append(next_val)
    print("\n",e+1, ". Values: ", values)
    for i in range(4):
        print("x = ", values[i], " f(x) = ", round(functions[e](values[i]), 2))
# Out:
#  1 . Values:  [3, 2.33, 2.24, 2.24]
# x =  3  f(x) =  4
# x =  2.33  f(x) =  0.43
# x =  2.24  f(x) =  0.02
# x =  2.24  f(x) =  0.02
#
#  2 . Values:  [3, 2.19, 1.81, 1.72]
# x =  3  f(x) =  22
# x =  2.19  f(x) =  5.5
# x =  1.81  f(x) =  0.93
# x =  1.72  f(x) =  0.09
#
#  3 . Values:  [3, 2.2, 2.25, 2.25]
# x =  3  f(x) =  0.23
# x =  2.2  f(x) =  -0.02
# x =  2.25  f(x) =  0.0
# x =  2.25  f(x) =  0.0
#
#  4 . Values:  [3, 2.1, 1.34, 0.86]
# x =  3  f(x) =  18.09
# x =  2.1  f(x) =  6.17
# x =  1.34  f(x) =  1.82
# x =  0.86  f(x) =  0.36
#
#  5 . Values:  [3, 1.65, 0.44, -0.47]
# x =  3  f(x) =  7.5
# x =  1.65  f(x) =  2.64
# x =  0.44  f(x) =  0.86
# x =  -0.47  f(x) =  0.22
#
#  6 . Values:  [3, 2.7, 2.72, 2.72]
# x =  3  f(x) =  0.1
# x =  2.7  f(x) =  -0.01
# x =  2.72  f(x) =  0.0
# x =  2.72  f(x) =  0.0
#
#  7 . Values:  [3, 2.64, 2.62, 2.62]
# x =  3  f(x) =  -0.36
# x =  2.64  f(x) =  -0.02
# x =  2.62  f(x) =  -0.0
# x =  2.62  f(x) =  -0.0
#
# ...

# %%
#Problem 5. Compute with Secant Method
import numpy as np

x = np.linspace (-3 , 3 , 100) # x value - continuous


#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5

#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5

#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5

#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2

#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5

#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1

#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5

#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

def getSlope(f, xvals, count):
    return (f(xvals[count + 1]) - f(xvals[count]))/(xvals[count +1] - xvals[count])
                                                    
def getIntercept(f, slope, xvals, count):
    return -slope * xvals[count + 1] + f(xvals[count + 1])

for e in range(len(functions)):
    a = 0
    b = 3
    xvals = []
    xvals.append(a)
    xvals.append(b)
    cols = ['r', 'b', 'g']
    for i in range (3):
        slope = getSlope(functions[e], xvals, i)
        intercept = getIntercept(functions[e], slope, xvals, i)

        next_val = round(-intercept/slope,2)
        xvals.append(next_val)
    print("\n", e+1, ". Values: ", xvals)
    for i in range(1,len(xvals)):
        print("x = ", xvals[i], " f(x) = ", round(functions[e](xvals[i]), 2))
# Out:
#  1 . Values:  [0, 3, 1.67, 2.14, 2.25]
# x =  3  f(x) =  4
# x =  1.67  f(x) =  -2.21
# x =  2.14  f(x) =  -0.42
# x =  2.25  f(x) =  0.06
#
#  2 . Values:  [0, 3, 0.56, 1.0, 3.13]
# x =  3  f(x) =  22
# x =  0.56  f(x) =  -4.82
# x =  1.0  f(x) =  -4.0
# x =  3.13  f(x) =  25.66
#
#  3 . Values:  [0, 3, 2.6, 2.22, 2.25]
# x =  3  f(x) =  0.23
# x =  2.6  f(x) =  0.11
# x =  2.22  f(x) =  -0.01
# x =  2.25  f(x) =  0.0
#
#  4 . Values:  [0, 3, 0.16, 0.28, 0.82]
# x =  3  f(x) =  18.09
# x =  0.16  f(x) =  -0.83
# x =  0.28  f(x) =  -0.68
# x =  0.82  f(x) =  0.27
#
#  5 . Values:  [0, 3, -0.21, -0.37, -0.85]
# x =  3  f(x) =  7.5
# x =  -0.21  f(x) =  0.36
# x =  -0.37  f(x) =  0.27
# x =  -0.85  f(x) =  0.05
#
#  6 . Values:  [0, 3, nan, nan, nan]
# x =  3  f(x) =  0.1
# x =  nan  f(x) =  nan
# x =  nan  f(x) =  nan
# x =  nan  f(x) =  nan
#
#  7 . Values:  [0, 3, 10.63, 0.45, -0.03]
# x =  3  f(x) =  -0.36
# x =  10.63  f(x) =  -1.43
# x =  0.45  f(x) =  -0.07
# ...

# %%
#Problem 6. Compute with Bisection Method
import numpy as np

x = np.linspace (-3 , 3 , 100) # x value - continuous


#1. f(x) = x^2 - 5
def f1(x):
    return pow(x,2) - 5
 
#2. f(x) = x^3 - 5
def f2(x):
    return pow(x,3) - 5

#3. f(x) = √x - 1.5
def f3(x):
    return np.sqrt(x) - 1.5

#4. f(x) = e^x - 2
def f4(x):
    return np.exp(x) - 2

#5. f(x) = 2^x - 0.5
def f5(x):
    return pow(2,x) - 0.5

#6. f(x) = log(x) - 1
def f6(x):
    return np.log(x) - 1

#7. f(x) = sin(x) - 0.5
def f7(x):
    return np.sin(x) - 0.5

#8. f(x) = cos(x) - 0.5
def f8(x):
    return np.cos(x) - 0.5

functions = [f1,f2,f3,f4,f5,f6,f7,f8]

def getNext(f, a, b, mid):
    if (f(a) < 0 and f(mid) > 0 or f(a) > 0 and f(mid) < 0):
        return "a"
    else:
        return "b"

for e in range(len(functions)):
    a = -3
    b = 3
    xvals = []
    cols = ['r', 'b', 'g']
    for i in range (3):
        mid = (a + b)/2
        xvals.append(mid)
        
        if getNext(functions[e], a, b, mid) == "a":
            b = mid
        else:
            a = mid

    print("\n", e+1, "Values: ", xvals)
    for i in range(len(xvals)):
        print("x = ", xvals[i], " f(x) = ", round(functions[e](xvals[i]), 2))
# Out:
#  1 Values:  [0.0, -1.5, -2.25]
# x =  0.0  f(x) =  -5.0
# x =  -1.5  f(x) =  -2.75
# x =  -2.25  f(x) =  0.06
#
#  2 Values:  [0.0, 1.5, 2.25]
# x =  0.0  f(x) =  -5.0
# x =  1.5  f(x) =  -1.62
# x =  2.25  f(x) =  6.39
#
#  3 Values:  [0.0, 1.5, 2.25]
# x =  0.0  f(x) =  -1.5
# x =  1.5  f(x) =  -0.28
# x =  2.25  f(x) =  0.0
#
#  4 Values:  [0.0, 1.5, 0.75]
# x =  0.0  f(x) =  -1.0
# x =  1.5  f(x) =  2.48
# x =  0.75  f(x) =  0.12
#
#  5 Values:  [0.0, -1.5, -0.75]
# x =  0.0  f(x) =  0.5
# x =  -1.5  f(x) =  -0.15
# x =  -0.75  f(x) =  0.09
#
#  6 Values:  [0.0, 1.5, 2.25]
# x =  0.0  f(x) =  -inf
# x =  1.5  f(x) =  -0.59
# x =  2.25  f(x) =  -0.19
#
#  7 Values:  [0.0, 1.5, 0.75]
# x =  0.0  f(x) =  -0.5
# x =  1.5  f(x) =  0.5
# x =  0.75  f(x) =  0.18
#
#  8 Values:  [0.0, -1.5, -0.75]
# x =  0.0  f(x) =  0.5
# x =  -1.5  f(x) =  -0.43
# x =  -0.75  f(x) =  0.23

# %%
#Problem 7. Compute roots exactly with SymPy
import numpy as np
import sympy as sym

x = sym.Symbol('x')


#1. f(x) = x^2 - 5
f1 = pow(x,2) - 5
 
#2. f(x) = x^3 - 5
f2 = pow(x,3) - 5

#3. f(x) = √x - 1.5
f3 = sym.sqrt(x) - 1.5

#4. f(x) = e^x - 2
f4 = sym.exp(x) - 2

#5. f(x) = 2^x - 0.5
f5 = pow(2,x) - 0.5

#6. f(x) = log(x) - 1
f6 = sym.log(x, 10) - 1

#7. f(x) = sin(x) - 0.5
f7 = sym.sin(x) - 0.5

#8. f(x) = cos(x) - 0.5
f8 = sym.cos(x) - 0.5


intr = sym.solve(f1, x)

functions = [f1,f2,f3,f4,f5,f6,f7,f8]
functions_text = ["f(x) = x^2 - 5", "f(x) = x^3 - 5", "f(x) = √x - 1.5", "f(x) = e^x - 2", "f(x) = 2^x - 0.5", "f(x) = log(x) - 1", "f(x) = sin(x) - 0.5", "f(x) = cos(x) - 0.5"]

for e in range(8):
    roots = sym.solve(functions[e], x)
    print("\n", e+1, ". ",functions_text[e])
    for i in range(len(roots)):
        print(i+1, " => ", round(roots[i],2))
# Out:
# After Integration :  [-sqrt(5), sqrt(5)] -2.24
#
#  1 .  f(x) = x^2 - 5
# 1  =>  -2.24
# 2  =>  2.24
#
#  2 .  f(x) = x^3 - 5
# 1  =>  1.71
# 2  =>  -0.85 - 1.48*I
# 3  =>  -0.85 + 1.48*I
#
#  3 .  f(x) = √x - 1.5
# 1  =>  2.25
#
#  4 .  f(x) = e^x - 2
# 1  =>  0.69
#
#  5 .  f(x) = 2^x - 0.5
# 1  =>  -1.00000000000000
#
#  6 .  f(x) = log(x) - 1
# 1  =>  10
#
#  7 .  f(x) = sin(x) - 0.5
# 1  =>  0.52
# 2  =>  2.62
#
#  8 .  f(x) = cos(x) - 0.5
# 1  =>  1.05
# 2  =>  5.24

# %%
#Check if vectors are parallel or perpendicular
def find(A, B):
 
    # Find A.B
    per = A[0] * B[0] + A[1] * B[1] + A[2] * B[2]
 
    # Find A X B
    par = (A[1] * B[2] - A[2] * B[1]) * (A[1] * B[2] - A[2] * B[1]) + (A[0] * B[2] - B[0] * A[2]) * \
        (A[0] * B[2] - B[0] * A[2]) + (A[0] * B[1] -
                                       A[1] * B[0]) * (A[0] * B[1] - A[1] * B[0])
 
    if (per == 0):
        return 2
 
    elif (par == 0):
        return 1
 
    else:
        return 0


a = [4, 5, 6]
b = [-3, 3, -0.5]
 
# Function call
#2 = perpendicular
#1 = parallel
#0 = none
print(find(a, b))
# Out:
# 2
